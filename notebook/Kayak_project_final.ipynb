# %% [markdown]
# ![Kayak](https://seekvectorlogo.com/wp-content/uploads/2018/01/kayak-vector-logo.png)
#
# # Plan your trip with Kayak
#
# ##  Description 📇
#
# <a href="https://www.kayak.com" target="_blank">Kayak</a> est un moteur de recherche de voyages qui aide les utilisateurs à planifier leur prochain voyage au meilleur prix.
#
# L'entreprise a été fondée en 2004 par Steve Hafner et Paul M. English. Après quelques tours de financement, Kayak a été acquis par Booking Holdings, qui détient désormais
#
# * <a href="https://booking.com/" target="_blank">Booking.com</a>
# * <a href="https://kayak.com/" target="_blank">Kayak</a>
# * <a href="https://www.priceline.com/" target="_blank">Priceline</a>
# * <a href="https://www.agoda.com/" target="_blank">Agoda</a>
# * <a href="https://Rentalcars.com/" target="_blank">RentalCars</a>
# * <a href="https://www.opentable.com/" target="_blank">OpenTable</a>
#
# Avec un chiffre d'affaires annuel de plus de 300 millions de dollars, Kayak opère dans presque tous les pays et dans toutes les langues pour aider ses utilisateurs à réserver des voyages à travers le monde.

# %% [markdown]
# ## Projet 🚧
#
# L'équipe marketing a besoin d'aide sur un nouveau projet. Après avoir effectué des recherches utilisateur, l'équipe a découvert que **70% de leurs utilisateurs qui planifient un voyage aimeraient avoir plus d'informations sur la destination vers laquelle ils se dirigent.**.
#
# De plus, les recherches utilisateur montrent que **les gens ont tendance à être méfiants à propos des informations qu'ils lisent s'ils ne connaissent pas la marque** qui a produit le contenu..
#
# Par conséquent, l'équipe marketing de Kayak souhaite créer une application qui recommandera aux gens où ils devraient planifier leurs prochaines vacances. L'application devrait être basée sur des données réelles concernant :
#
# * La météo
# * Les hôtels dans la région
#
# L'application devrait ensuite être en mesure de recommander les meilleures destinations et hôtels

# %% [markdown]
# ## Goals 🎯
#
# * Scraping des données des destinations
# * Obtention des Données météorologiques
# * Récupération des Infos sur les Hôtels
# * Stockage des données dans un Data Lake
# * Extraction, Transformation et Chargement (ETL) des données

# %% [markdown]
# ## Scope of this project 🖼️
#
# L'équipe marketing souhaite se concentrer d'abord sur les meilleures villes où voyager en France.  <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> Voici les 35 meilleures villes à visiter en France.:
#
# ```python
# ["Mont Saint Michel",
# "St Malo",
# "Bayeux",
# "Le Havre",
# "Rouen",
# "Paris",
# "Amiens",
# "Lille",
# "Strasbourg",
# "Chateau du Haut Koenigsbourg",
# "Colmar",
# "Eguisheim",
# "Besancon",
# "Dijon",
# "Annecy",
# "Grenoble",
# "Lyon",
# "Gorges du Verdon",
# "Bormes les Mimosas",
# "Cassis",
# "Marseille",
# "Aix en Provence",
# "Avignon",
# "Uzes",
# "Nimes",
# "Aigues Mortes",
# "Saintes Maries de la mer",
# "Collioure",
# "Carcassonne",
# "Ariege",
# "Toulouse",
# "Montauban",
# "Biarritz",
# "Bayonne",
# "La Rochelle"]
# ```
#
# Votre équipe devrait se concentrer uniquement sur les villes mentionnées ci-dessus pour votre projet.

# %% [markdown]
# # Import des librairies

# %%
# !pip install folium

# %%
import requests
import pandas as pd
import plotly.express as px
import boto3
import ast
import json
import folium

from io import BytesIO
from branca.element import Figure
from sqlalchemy import create_engine, text

# %% [markdown]
# # Obtention des données en utilisant les API

# %%
# Liste des villes pour lesquelles nous voulons obtenir des coordonnées GPS
cities = [
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen", "Paris",
    "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg", "Colmar",
    "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble", "Lyon",
    "Gorges du Verdon", "Bormes les Mimosas", "Cassis", "Marseille",
    "Aix en Provence", "Avignon", "Uzes", "Nimes", "Aigues Mortes",
    "Saintes Maries de la mer", "Collioure", "Carcassonne", "Ariege",
    "Toulouse", "Montauban", "Biarritz", "Bayonne", "La Rochelle"
]

# %% [markdown]
# ### 1. Obtention des coodonnées GPS des villes via l'API Nominatim.

# %% [markdown]
# Dans cette étape, Nous utilisons l'API Nominatim d'OpenStreetMap pour obtenir les coordonnées géographiques (latitude et longitude) de diverses villes. Pour cela, les espaces dans les noms des villes seront remplacés par des '+' afin d'améliorer la lisibilité des URL de requête.
#
# Chaque ville sera requêtée via une méthode GET, et les réponses obtenues, contenant les coordonnées, seront converties en JSON.
#
# Les données pertinentes seront ensuite extraites et stockées dans un DataFrame pandas. Ce processus sera répété pour chaque ville, compilant toutes les coordonnées dans le DataFrame coordinates_df.

# %%
# Fonction pour interroger l'API Nominatim et obtenir les coordonnées GPS
def get_coordinates(city):
    # Remplace les espaces par des caractères '+'
    city = city.replace(' ', '+')
    # Défini l'URL de requête avec la ville spécifiée
    url = f"https://nominatim.openstreetmap.org/search?city={city}&format=json"
    
    # Exécute la requête GET à l'API Nominatim
    response = requests.get(url)
    
    # Vérifie si la requête a réussi
    if response.status_code == 200:
        # Obtenir les données JSON de la réponse
        data = response.json()
        return data[0]['lat'], data[0]['lon']
    else:
        return None, None

# %%
# Création d'un DataFrame pour stocker les informations des coordonnées GPS
coordinates_df = pd.DataFrame(columns=['City', 'Latitude', 'Longitude'])

# %%
# Boucle sur la liste des villes pour obtenir les coordonnées pour chaque ville

for city in cities:
    lat, lon = get_coordinates(city)
    new_row = pd.DataFrame({
        'City': [city],
        'Latitude': [lat],
        'Longitude': [lon]
    })
    coordinates_df = pd.concat([coordinates_df, new_row], ignore_index=True)

coordinates_df
# Out:
#                             City            Latitude           Longitude
# 0              Mont Saint Michel          48.6359541  -1.511459954959514
# 1                        St Malo           49.314695         -96.9538228
# 2                         Bayeux          49.2764624          -0.7024738
# 3                       Le Havre          49.4938975           0.1079732
# 4                          Rouen          49.4404591           1.0939658
# 5                          Paris          48.8588897  2.3200410217200766
# 6                         Amiens          49.8941708           2.2956951
# 7                          Lille          50.6365654           3.0635282
# 8                     Strasbourg           48.584614           7.7507127
# 9   Chateau du Haut Koenigsbourg          48.2495226           7.3454923
# 10                        Colmar          48.0777517           7.3579641
# 11                     Eguisheim          48.0447968           7.3079618
# 12                      Besancon          47.2380222           6.0243622
# 13                         Dijon          47.3215806           5.0414701
# 14                        Annecy          45.8992348           6.1288847
# 15                      Grenoble          45.1875602           5.7357819
# 16                          Lyon          45.7578137           4.8320114
# 17              Gorges du Verdon          43.7496562           6.3285616
# 18            Bormes les Mimosas          43.1506968           6.3419285
# 19                        Cassis          43.2140359           5.5396318
# 20                     Marseille          43.2961743           5.3699525
# 21               Aix en Provence          43.5298424           5.4474738
# 22                       Avignon          43.9492493           4.8059012
# 23                          Uzes          44.0121279           4.4196718
# 24                         Nimes          43.8374249           4.3600687
# 25                 Aigues Mortes          43.5661521             4.19154
# 26      Saintes Maries de la mer          43.4515922           4.4277202
# 27                     Collioure            42.52505           3.0831554
# 28                   Carcassonne          43.2130358           2.3491069
# 29                        Ariege         51.18111155  -55.98447423947262
# 30                      Toulouse          43.6044622           1.4442469
# 31                     Montauban          44.0175835           1.3549991
# 32                      Biarritz  43.471143749999996  -1.552726590666314
# 33                       Bayonne          43.4945144          -1.4736657
# 34                   La Rochelle          46.1591126          -1.1520434

# %% [markdown]
# ### 2. Obtention de données de temps (weather) par le biais de l'api open-weather.

# %% [markdown]
# Nous utilisons l'API One Call d'OpenWeatherMap pour récupérer les données météorologiques complètes (latitude et longitude) en utilisant une clé API obtenue après inscription sur leur site.
#
# Après avoir construit l'URL de requête avec les coordonnées géographiques spécifiques, nous effectuons une requête GET pour chaque ensemble de coordonnées.
#
# Les réponses obtenues seront converties en JSON, et les données météorologiques pertinentes seront extraites et stockées dans une colonne 'Weather' du DataFrame coordinates_df.
#
# Ce processus sera répété pour chaque ligne du DataFrame, et enfin, les données seront sauvegardées dans un fichier CSV coordinates.csv.

# %%
# Clé API obtenu suite à inscription sur le site
api_key = # Votre clé API Open-weather

# %%
# Fonction pour récupérer les données météorologiques en utilisant l'API OpenWeatherMap. 
def get_weather(lat, lon):
    url = f"https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude=minutely,hourly,alert&units=metric&appid={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        weather_data = response.json()
        return weather_data
    else:
        print(f"Failed to get weather data: Status code {response.status_code}, Response: {response.text}")
        return None

# %%
# Applique la fonction à chaque ligne de `coordinates_df` pour récupérer les données météorologiques détaillées.
coordinates_df['Weather'] = coordinates_df.apply(lambda row: get_weather(row['Latitude'], row['Longitude']), axis=1)

coordinates_df
# Out:
#                             City            Latitude           Longitude  \
# 0              Mont Saint Michel          48.6359541  -1.511459954959514
# 1                        St Malo           49.314695         -96.9538228
# 2                         Bayeux          49.2764624          -0.7024738
# 3                       Le Havre          49.4938975           0.1079732
# 4                          Rouen          49.4404591           1.0939658
# 5                          Paris          48.8588897  2.3200410217200766
# 6                         Amiens          49.8941708           2.2956951
# 7                          Lille          50.6365654           3.0635282
# 8                     Strasbourg           48.584614           7.7507127
# 9   Chateau du Haut Koenigsbourg          48.2495226           7.3454923
# 10                        Colmar          48.0777517           7.3579641
# 11                     Eguisheim          48.0447968           7.3079618
# 12                      Besancon          47.2380222           6.0243622
# 13                         Dijon          47.3215806           5.0414701
# 14                        Annecy          45.8992348           6.1288847
# 15                      Grenoble          45.1875602           5.7357819
# 16                          Lyon          45.7578137           4.8320114
# 17              Gorges du Verdon          43.7496562           6.3285616
# 18            Bormes les Mimosas          43.1506968           6.3419285
# 19                        Cassis          43.2140359           5.5396318
# 20                     Marseille          43.2961743           5.3699525
# 21               Aix en Provence          43.5298424           5.4474738
# 22                       Avignon          43.9492493           4.8059012
# 23                          Uzes          44.0121279           4.4196718
# 24                         Nimes          43.8374249           4.3600687
# 25                 Aigues Mortes          43.5661521             4.19154
# 26      Saintes Maries de la mer          43.4515922           4.4277202
# 27                     Collioure            42.52505           3.0831554
# 28                   Carcassonne          43.2130358           2.3491069
# 29                        Ariege         51.18111155  -55.98447423947262
# 30                      Toulouse          43.6044622           1.4442469
# 31                     Montauban          44.0175835           1.3549991
# 32                      Biarritz  43.471143749999996  -1.552726590666314
# 33                       Bayonne          43.4945144          -1.4736657
# 34                   La Rochelle          46.1591126          -1.1520434
#
#                                               Weather
# 0   {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1   {'lat': 49.3147, 'lon': -96.9538, 'timezone': ...
# 2   {'lat': 49.2765, 'lon': -0.7025, 'timezone': '...
# 3   {'lat': 49.4939, 'lon': 0.108, 'timezone': 'Eu...
# 4   {'lat': 49.4405, 'lon': 1.094, 'timezone': 'Eu...
# 5   {'lat': 48.8589, 'lon': 2.32, 'timezone': 'Eur...
# 6   {'lat': 49.8942, 'lon': 2.2957, 'timezone': 'E...
# 7   {'lat': 50.6366, 'lon': 3.0635, 'timezone': 'E...
# 8   {'lat': 48.5846, 'lon': 7.7507, 'timezone': 'E...
# 9   {'lat': 48.2495, 'lon': 7.3455, 'timezone': 'E...
# 10  {'lat': 48.0778, 'lon': 7.358, 'timezone': 'Eu...
# 11  {'lat': 48.0448, 'lon': 7.308, 'timezone': 'Eu...
# 12  {'lat': 47.238, 'lon': 6.0244, 'timezone': 'Eu...
# 13  {'lat': 47.3216, 'lon': 5.0415, 'timezone': 'E...
# 14  {'lat': 45.8992, 'lon': 6.1289, 'timezone': 'E...
# 15  {'lat': 45.1876, 'lon': 5.7358, 'timezone': 'E...
# 16  {'lat': 45.7578, 'lon': 4.832, 'timezone': 'Eu...
# 17  {'lat': 43.7497, 'lon': 6.3286, 'timezone': 'E...
# 18  {'lat': 43.1507, 'lon': 6.3419, 'timezone': 'E...
# 19  {'lat': 43.214, 'lon': 5.5396, 'timezone': 'Eu...
# 20  {'lat': 43.2962, 'lon': 5.37, 'timezone': 'Eur...
# 21  {'lat': 43.5298, 'lon': 5.4475, 'timezone': 'E...
# 22  {'lat': 43.9492, 'lon': 4.8059, 'timezone': 'E...
# 23  {'lat': 44.0121, 'lon': 4.4197, 'timezone': 'E...
# 24  {'lat': 43.8374, 'lon': 4.3601, 'timezone': 'E...
# 25  {'lat': 43.5662, 'lon': 4.1915, 'timezone': 'E...
# 26  {'lat': 43.4516, 'lon': 4.4277, 'timezone': 'E...
# 27  {'lat': 42.5251, 'lon': 3.0832, 'timezone': 'E...
# 28  {'lat': 43.213, 'lon': 2.3491, 'timezone': 'Eu...
# 29  {'lat': 51.1811, 'lon': -55.9845, 'timezone': ...
# 30  {'lat': 43.6045, 'lon': 1.4442, 'timezone': 'E...
# 31  {'lat': 44.0176, 'lon': 1.355, 'timezone': 'Eu...
# 32  {'lat': 43.4711, 'lon': -1.5527, 'timezone': '...
# 33  {'lat': 43.4945, 'lon': -1.4737, 'timezone': '...
# 34  {'lat': 46.1591, 'lon': -1.152, 'timezone': 'E...

# %%
# Transformation de données en fichier csv
coordinates_df.to_csv('coordinates.csv', index=False)

# %% [markdown]
# ### 3. Déterminer les 7 villes ayant le temps le plus beau.

# %% [markdown]
# Nous utilisons les données météorologiques collectées précédemment pour calculer les scores de température moyenne et de précipitation totale de chaque ville. La fonction calculate_weather_scores extrait et somme les températures diurnes et les précipitations (si présentes) pour chaque jour des données météo fournies. Ces scores sont ensuite ajoutés au DataFrame coordinates_df.
#
# Après avoir calculé ces scores pour chaque ville, nous trions les villes pour identifier celles avec les températures les plus élevées et les précipitations les plus faibles, favorisant ainsi les destinations avec un climat agréable.
#
# Les cinq premières villes, qualifiées de destinations ayant le meilleur temps, seront ensuite visualisées sur une carte centrée sur la France.
#
# Cette carte, générée avec Plotly, mettra en évidence ces villes en fonction de leur température moyenne et de leurs précipitations, offrant ainsi une représentation graphique  des meilleures destinations selon le climat.

# %%
# Fonction de calcule de la température moyenne et la précipitation totale sur la période couverte par les données météorologiques.
def calculate_weather_scores(weather_data):
    total_temp = 0
    total_precipitation = 0
    for day in weather_data['daily']:
        total_temp += day['temp']['day']
        # Ajoute les précipitations seulement si elles sont prévues
        total_precipitation += day.get('rain', 0)
    average_temp = total_temp / len(weather_data['daily'])
    return average_temp, total_precipitation

# %%
# Applique la fonction pour chaque ligne de `coordinates_df et stock les résultats dans les colonnes 'AverageTemp' et 'TotalPrecipitation'.
coordinates_df[['AverageTemp', 'TotalPrecipitation']] = coordinates_df.apply(lambda row: calculate_weather_scores(row['Weather']), axis=1, result_type='expand')

# %%
coordinates_df.head()
# Out:
#                 City    Latitude           Longitude  \
# 0  Mont Saint Michel  48.6359541  -1.511459954959514
# 1            St Malo   49.314695         -96.9538228
# 2             Bayeux  49.2764624          -0.7024738
# 3           Le Havre  49.4938975           0.1079732
# 4              Rouen  49.4404591           1.0939658
#
#                                              Weather  AverageTemp  \
# 0  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...     18.28375
# 1  {'lat': 49.3147, 'lon': -96.9538, 'timezone': ...     17.33375
# 2  {'lat': 49.2765, 'lon': -0.7025, 'timezone': '...     16.96625
# 3  {'lat': 49.4939, 'lon': 0.108, 'timezone': 'Eu...     16.32625
# 4  {'lat': 49.4405, 'lon': 1.094, 'timezone': 'Eu...     17.92250
#
#    TotalPrecipitation
# 0               23.87
# 1               32.06
# 2               14.22
# 3               18.44
# 4               31.45

# %%
# Ascending=False car nous voulons afficher des températures élevées et ascending=True car nous voulons de faibles précipitations pour identifier les meilleurs villes
nice_weather_cities = coordinates_df.sort_values(by=['AverageTemp', 'TotalPrecipitation'], ascending=[False, True])

# %%
# Transformation des données de temps en csv
nice_weather_cities.to_csv('nice_weather_cities.csv', index=False)

# %% [markdown]
# # Obtention des données par Scrapping.

# %% [markdown]
# Nous utilisons un script Python pour extraire des données d'hôtels depuis Booking.com à l'aide de la bibliothèque Scrapy. Le script initialise une Spider qui navigue sur les pages de résultats de recherche des villes françaises de notre liste.
#
# Pour chaque hôtel listé, le script extrait le nom, l'URL, la note, et la description, puis utilise une fonction auxiliaire pour récupérer les coordonnées géographiques de chaque hôtel via l'API Nominatim d'OpenStreetMap. Ces données sont ensuite compilées en un fichier JSON hotels.json.

# %%
#!python scraping_booking.py

# %% [markdown]
# ## Chargement et fusion des données

# %% [markdown]
# Dans cette etape, nous chargeons les données des hôtels depuis un fichier JSON dans un DataFrame Pandas, renommons certaines colonnes pour la clarté, et fusionnons ce DataFrame avec un autre contenant les coordonnées des villes.
#
# Le DataFrame final, qui combine les informations des hôtels et des villes, sera ensuite enregistré dans un fichier CSV et stocké dans un S3 pour des analyses futures.

# %%
# Lecture du fichier Json récupéré lors du scraping.
booking_df = pd.read_json('hotels.json')
booking_df.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description   Latitude  Longitude
# 0  Hotel Vert offers pastel-coloured rooms with a...  48.614700  -1.509617
# 1  Composed of 2 different buildings, Les Terrass...  48.635349  -1.510379
# 2  This Mercure is situated in parkland just 2 km...  48.614247  -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...  48.616263  -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...  48.617587  -1.510396

# %%
# Rennomage des columns pour plus de clarté et éviter des confusion lors du merge des df.
booking_df.rename(columns={'Latitude': 'lat_hotels', 'Longitude': 'lon_hotels'}, inplace=True)
booking_df.head(1)
# Out:
#                 City  Hotel Name  \
# 0  Mont Saint Michel  Hôtel Vert
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
#
#                                          Description  lat_hotels  lon_hotels
# 0  Hotel Vert offers pastel-coloured rooms with a...     48.6147   -1.509617

# %%
# Fusion des df répertoriant les df et des villes en un seul df.
df_complete = pd.merge(booking_df, coordinates_df, on='City')
df_complete.head(1)
# Out:
#                 City  Hotel Name  \
# 0  Mont Saint Michel  Hôtel Vert
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...     48.6147   -1.509617
#
#      Latitude           Longitude  \
# 0  48.6359541  -1.511459954959514
#
#                                              Weather  AverageTemp  \
# 0  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...     18.28375
#
#    TotalPrecipitation
# 0               23.87

# %%
# Transformation du df final en .csv
df_complete.to_csv('df_complete.csv', index=False)

# %% [markdown]
# ## Affichage des cartes des 5 meilleurs villes et des 20 meilleurs hotels.

# %% [markdown]
# Comme demandée dans l'énoncé, nous affichons des 5 villes ayants les meilleurs températures dans un 1ere carte et les 20 hotels ayant les meilleurs score pour ces villes dans une seconde carte. Pour des soucis de précision et d'intéractivité, nous utiliserons la librairie Folium.

# %%
# Plot des 5 meilleurs destinations de Frances selon la température.
# Crée une figure pour contenir la carte avec un titre
villes_fig = Figure(width=800, height=400)
villes_fig.html.add_child(folium.Element("<h3 style='text-align:center;margin-top:20px;'>Top 5 des villes avec la meilleure météo in France</h3>"))

# Crée une carte centrée autour de la France
map_france = folium.Map(location=[46.2276, 2.2137], zoom_start=6, tiles='OpenStreetMap')
villes_fig.add_child(map_france)

# Ajoute des marqueurs pour les top 5 destinations
for _, row in top_5_destinations.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['City']}: Temp {row['AverageTemp']}°C, Precip {row['TotalPrecipitation']}mm",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(map_france)

# Affiche la carte avec le titre
villes_fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05b4e596186eda4726d612149780b633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;text-align:center;margin-top:20px;&#x27;&gt;Top 5 Cities with Nice Weather in France&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05b4e596186eda4726d612149780b633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05b4e596186eda4726d612149780b633 = L.map(
#                 &quot;map_05b4e596186eda4726d612149780b633&quot;,
#                 {
#                     center: [46.2276, 2.2137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c3497313d93adcc4c6ce605504d86b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c3497313d93adcc4c6ce605504d86b4.addTo(map_05b4e596186eda4726d612149780b633);
#
#
#             var marker_3477f33ad6dea9235873811b6c16a2be = L.marker(
#                 [43.5298424, 5.4474738],
#                 {}
#             ).addTo(map_05b4e596186eda4726d612149780b633);
#
#
#             var icon_470817a2b53ee0bdac29ca82cb4b4a8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3477f33ad6dea9235873811b6c16a2be.setIcon(icon_470817a2b53ee0bdac29ca82cb4b4a8d);
#
#
#         var popup_d6a7bdbe8591482ab221bc3fb2998612 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d06cf828fb0c43c3ecbe121d2dae0ab = $(`&lt;div id=&quot;html_2d06cf828fb0c43c3ecbe121d2dae0ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aix en Provence: Temp 27.064999999999998°C, Precip 0.0mm&lt;/div&gt;`)[0];
#                 popup_d6a7bdbe8591482ab221bc3fb2998612.setContent(html_2d06cf828fb0c43c3ecbe121d2dae0ab);
#
#
#
#         marker_3477f33ad6dea9235873811b6c16a2be.bindPopup(popup_d6a7bdbe8591482ab221bc3fb2998612)
#         ;
#
#
#
#
#             var marker_1c810bd06a9c6df1c20628c8259db173 = L.marker(
#                 [43.9492493, 4.8059012],
#                 {}
#             ).addTo(map_05b4e596186eda4726d612149780b633);
#
#
#             var icon_07e8cb4b35037650b54ff427ab7dbbbe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c810bd06a9c6df1c20628c8259db173.setIcon(icon_07e8cb4b35037650b54ff427ab7dbbbe);
#
#
#         var popup_90ca6664154cd575ca2a6e2728cdc584 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5a08fa54f2082cde76e2bf3fcd1cf6b = $(`&lt;div id=&quot;html_c5a08fa54f2082cde76e2bf3fcd1cf6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avignon: Temp 26.64125°C, Precip 0.27mm&lt;/div&gt;`)[0];
#                 popup_90ca6664154cd575ca2a6e2728cdc584.setContent(html_c5a08fa54f2082cde76e2bf3fcd1cf6b);
#
#
#
#         marker_1c810bd06a9c6df1c20628c8259db173.bindPopup(popup_90ca6664154cd575ca2a6e2728cdc584)
#         ;
#
#
#
#
#             var marker_b8ab2ff775bd08936d62e805f5eafe9c = L.marker(
#                 [43.8374249, 4.3600687],
#                 {}
#             ).addTo(map_05b4e596186eda4726d612149780b633);
#
#
#             var icon_8798ec75ed9a5a1d6029e8241ba5e937 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8ab2ff775bd08936d62e805f5eafe9c.setIcon(icon_8798ec75ed9a5a1d6029e8241ba5e937);
#
#
#         var popup_036e3baa7b8305a67feb5820b0543459 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_963bcdd13bbb7561ab1aa55c3469830b = $(`&lt;div id=&quot;html_963bcdd13bbb7561ab1aa55c3469830b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nimes: Temp 26.5675°C, Precip 3.31mm&lt;/div&gt;`)[0];
#                 popup_036e3baa7b8305a67feb5820b0543459.setContent(html_963bcdd13bbb7561ab1aa55c3469830b);
#
#
#
#         marker_b8ab2ff775bd08936d62e805f5eafe9c.bindPopup(popup_036e3baa7b8305a67feb5820b0543459)
#         ;
#
#
#
#
#             var marker_da7948e7c4658942c7246b90e89d739e = L.marker(
#                 [43.2130358, 2.3491069],
#                 {}
#             ).addTo(map_05b4e596186eda4726d612149780b633);
#
#
#             var icon_16796d019090808b845c2b1e71026270 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&qu

# %%
# Remplace les NaN dans la colonne 'Score' par 0 et élimine les lignes avec des coordonnées NaN
df_complete['Score'].fillna(0, inplace=True)
df_complete.dropna(subset=['lat_hotels', 'lon_hotels'], inplace=True)

# Filtre les hôtels pour ne garder que ceux dans les top 5 villes
top_cities = top_5_destinations['City'].tolist()
filtered_hotels = df_complete[df_complete['City'].isin(top_cities)]

# Sélectionne les 20 meilleurs hôtels pour chaque ville en fonction du score
top_hotels = filtered_hotels.groupby('City').apply(lambda x: x.nlargest(20, 'Score')).reset_index(drop=True)

# %%
# Crée une nouvelle figure pour la carte des hôtels
hotel_fig = Figure(width=800, height=400)
hotel_fig.html.add_child(folium.Element("<h3 style='text-align:center;margin-top:20px;'>Top 20 des hotels pour chacune des villes</h3>"))

# Crée une carte centrée autour de la France
hotel_map = folium.Map(location=[46.2276, 2.2137], zoom_start=6, tiles='OpenStreetMap')
hotel_fig.add_child(hotel_map)

# Ajoute des marqueurs pour les hôtels sélectionnés
for _, hotel in top_hotels.iterrows():
    folium.Marker(
        location=[hotel['lat_hotels'], hotel['lon_hotels']],
        popup=f"{hotel['Hotel Name']}: Score {hotel['Score']}<br><a href='{hotel['Hotel URL']}' target='_blank'>Book Now</a>",
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(hotel_map)

# Affiche la carte avec les hôtels
hotel_fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25286c4ee0003575bb1120ef8f6c5122 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 style=&#x27;text-align:center;margin-top:20px;&#x27;&gt;Top 20 Hotels in Each of Top 5 Cities with Nice Weather&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25286c4ee0003575bb1120ef8f6c5122&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25286c4ee0003575bb1120ef8f6c5122 = L.map(
#                 &quot;map_25286c4ee0003575bb1120ef8f6c5122&quot;,
#                 {
#                     center: [46.2276, 2.2137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb5e654f561e25b67498381fb16b3442 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb5e654f561e25b67498381fb16b3442.addTo(map_25286c4ee0003575bb1120ef8f6c5122);
#
#
#             var marker_8786ab02f1339af4324ead41ab6f5ccc = L.marker(
#                 [43.5301204, 5.4489216],
#                 {}
#             ).addTo(map_25286c4ee0003575bb1120ef8f6c5122);
#
#
#             var icon_7bfabbdb91e0ae068f9a106836c5d4f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8786ab02f1339af4324ead41ab6f5ccc.setIcon(icon_7bfabbdb91e0ae068f9a106836c5d4f7);
#
#
#         var popup_0b6c3fb0375d30b3f66cc0ae791143df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d68917c84ec43e23345bdb57692e717 = $(`&lt;div id=&quot;html_2d68917c84ec43e23345bdb57692e717&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Studio Aix Centre Historique: Score 10.0&lt;br&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/charmant-appartement-hypercentre-aix-en-provence.en-gb.html?aid=304142&amp;label=gen173nr-1FCAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYAQm4ARfIAQzYAQHoAQH4AQOIAgGoAgO4Apmz3bIGwAIB0gIkMjhhYmEwYzctZTY1Ny00NzNhLTkyMDAtNDg5MDhlYjcwYWU52AIF4AIB&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=21&amp;hapos=21&amp;sr_order=popularity&amp;srpvid=118e74cce160017d&amp;srepoch=1717000602&amp;from=searchresults#hotelTmpl&#x27; target=&#x27;_blank&#x27;&gt;Book Now&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_0b6c3fb0375d30b3f66cc0ae791143df.setContent(html_2d68917c84ec43e23345bdb57692e717);
#
#
#
#         marker_8786ab02f1339af4324ead41ab6f5ccc.bindPopup(popup_0b6c3fb0375d30b3f66cc0ae791143df)
#         ;
#
#
#
#
#             var marker_e502202e3c4bc421c7cf42ce54535e58 = L.marker(
#                 [43.528465619432, 5.452499735058],
#                 {}
#             ).addTo(map_25286c4ee0003575bb1120ef8f6c5122);
#
#
#             var icon_93ad23fec30882f0ec16be17b843dc39 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e502202e3c4bc421c7cf42ce54535e58.setIcon(icon_93ad23fec30882f0ec16be17b843dc39);
#
#
#         var popup_87787d0f67279cc36c1627e3bfc3211f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca0429b5c254f0480599a733e5d13759 = $(`&lt;div id=&quot;html_ca0429b5c254f0480599a733e5d13759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le Mini - Un voyage en Provence: Score 9.5&lt;br&gt;&lt;a href=&#x27;https://www.booking.com/hotel/fr/studio-terrasse-en-duplex-au-coeur-d-aix-en-provence.en-gb.html?aid=304142&amp;label=gen173nr-1FCAQoggJCFnNlYXJjaF9haXggZW4gcHJvdmVuY2VIM1gEaE2IAQGYAQm4ARfIAQzYAQHoAQH4AQOIAgGoAgO4Apmz3bIGwAIB0gIkMjhhYmEwYzctZTY1Ny00NzNhLTkyMDAtNDg5MDhlYjcwYWU52AIF4AIB&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=15&amp;hapos=15&amp;sr_order=popularity&amp;srpvid=118e74cce160017d&amp;srepoch=1717000602&amp;from=searchresults#hotelTmpl&#x27; target=&#x27;_blank&#x27;&gt;Book Now&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_87787d0f67279cc36c1627e3bfc3211f.setContent(html_ca0429b5c254f0480599a733e5d13759);
#
#
#
#         marker_e502202e3c4bc421c7cf42ce54535e58.bindPopup(popup_87787d0f67279cc36c1627e3bfc3211f)
#         ;
#
#
#
#
#             var marker_596b58e3fe28c9efdadffb598607cb89 = L.marker(
#                 [43.49241698952985, 5.429788827896118],
#                 {}
#             ).addTo(map_25286c4ee0003575bb1120ef8f6c5122);
#
#
#             var icon_06bdb007ad1ca92976641f4cf7716e34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;m

# %% [markdown]
# ## Stocker le dataset dans un data lake S3

# %% [markdown]
# Nous configurons une session AWS S3 en utilisant nos identifiants d'accès spécifiques pour interagir avec le service de stockage cloud puis nous chargeonsle df complet en format csv  dans un bucket S3.
#
# Ensuite nous  lisons le fichier directement depuis S3 pour confirmer que les données sont correctement récupérées. Cette approche assure que les données sont correctement stockées et accessibles dans notre datalake sur S3.

# %%
# Charge la session S3 et les ressources nécessaires
session = boto3.Session(
    aws_access_key_id= # Votre clé d'accès AWS , 
    aws_secret_access_key= # Votre clé secrète AWS  
)
s3 = session.resource('s3')

# %%
# Upload le fichier dans S3
s3.Bucket('kayak-project-datalake').upload_file('df_complete.csv', 'data-kayak-project/df_complete.csv')

# %%
# Téléchargement et de lecture d'un fichier CSV depuis un bucket S3
try:
    obj = s3.Object('kayak-project-datalake', 'data-kayak-project/df_complete.csv')
    df_s3 = pd.read_csv(BytesIO(obj.get()['Body'].read()))
    print("File downloaded successfully")
except Exception as e:
    print(e)
# Out:
# File downloaded successfully

# %%
# Sanity check du df
df_s3.head(2)
# Out:
#                 City             Hotel Name  \
# 0  Mont Saint Michel             Hôtel Vert
# 1  Mont Saint Michel  Les Terrasses Poulard
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
#
#     Latitude  Longitude                                            Weather  \
# 0  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
#
#    AverageTemp  TotalPrecipitation
# 0     18.28375               23.87
# 1     18.28375               23.87

# %% [markdown]
# ## Transformation du dataframe

# %% [markdown]
# Dans cette section, nous voulons enrichir le DataFrame df_s3 avec des caractéristiques météorologiques détaillées extraites de la colonne Weather pour offrir une analyse plus approfondie des conditions climatiques de chaque lieu. Celà permet une meilleur lisibilitée et de tirer pleinement du potentiel d'information que contient la colonne "weather"

# %%
df_s3[['City', 'Hotel Name', 'Hotel URL', 'Score', 'Description', 'lat_hotels','lon_hotels', 'Latitude', 'Longitude', 'AverageTemp','TotalPrecipitation']]
# Out:
#                   City                                         Hotel Name  \
# 0    Mont Saint Michel                                         Hôtel Vert
# 1    Mont Saint Michel                              Les Terrasses Poulard
# 2    Mont Saint Michel                          Mercure Mont Saint Michel
# 3    Mont Saint Michel                                   Le Relais Du Roy
# 4    Mont Saint Michel                             Le Relais Saint Michel
# ..                 ...                                                ...
# 871        La Rochelle   Première Classe La Rochelle Centre - Les Minimes
# 872        La Rochelle                         360 degrés sur la rochelle
# 873        La Rochelle   La Belle Amarre-Bed and Breakfast-Maison d'Hôtes
# 874        La Rochelle                                  Hôtel La Fabrique
# 875        La Rochelle  Charmant cocon iodé cosy équipé, baigné de lum...
#
#                                              Hotel URL  Score  \
# 0    https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1    https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2    https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3    https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4    https://www.booking.com/hotel/fr/le-relais-sai...    8.0
# ..                                                 ...    ...
# 871  https://www.booking.com/hotel/fr/premia-re-cla...    7.5
# 872  https://www.booking.com/hotel/fr/360-degres-su...    9.1
# 873  https://www.booking.com/hotel/fr/la-belle-amar...    9.4
# 874  https://www.booking.com/hotel/fr/la-fabrique-l...    8.4
# 875  https://www.booking.com/hotel/fr/charmand-coco...    9.1
#
#                                            Description  lat_hotels  \
# 0    Hotel Vert offers pastel-coloured rooms with a...   48.614700
# 1    Composed of 2 different buildings, Les Terrass...   48.635349
# 2    This Mercure is situated in parkland just 2 km...   48.614247
# 3    Le Relais Du Roy is a 3-star hotel situated ne...   48.616263
# 4    Le Relais Saint Michel is an hotel facing the ...   48.617587
# ..                                                 ...         ...
# 871  Première Classe La Rochelle Centre - Les Minim...   46.147028
# 872                          Managed by a private host   46.166189
# 873                          Managed by a private host   46.158662
# 874  Hôtel La Fabrique offers accommodation in La R...   46.156155
# 875  Boasting a bar, the recently renovated Charman...   46.162449
#
#      lon_hotels   Latitude  Longitude  AverageTemp  TotalPrecipitation
# 0     -1.509617  48.635954  -1.511460     18.28375               23.87
# 1     -1.510379  48.635954  -1.511460     18.28375               23.87
# 2     -1.510545  48.635954  -1.511460     18.28375               23.87
# 3     -1.510906  48.635954  -1.511460     18.28375               23.87
# 4     -1.510396  48.635954  -1.511460     18.28375               23.87
# ..          ...        ...        ...          ...                 ...
# 871   -1.153085  46.159113  -1.152043     19.10875               13.32
# 872   -1.146359  46.159113  -1.152043     19.10875               13.32
# 873   -1.155056  46.159113  -1.152043     19.10875               13.32
# 874   -1.148583  46.159113  -1.152043     19.10875               13.32
# 875   -1.148847  46.159113  -1.152043     19.10875               13.32
#
# [876 rows x 11 columns]

# %%
# Identification des informations contenues dans la colonne weather pour la 1ere ligne. 
print(df_s3['Weather'].iloc[0])
# Out:
# {'lat': 48.636, 'lon': -1.5115, 'timezone': 'Europe/Paris', 'timezone_offset': 7200, 'current': {'dt': 1718210589, 'sunrise': 1718165002, 'sunset': 1718222924, 'temp': 16.28, 'feels_like': 15.61, 'pressure': 1019, 'humidity': 63, 'dew_point': 9.23, 'uvi': 1.35, 'clouds': 4, 'visibility': 10000, 'wind_speed': 1.79, 'wind_deg': 331, 'wind_gust': 4.92, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}, 'daily': [{'dt': 1718193600, 'sunrise': 1718165002, 'sunset': 1718222924, 'moonrise': 1718186340, 'moonset': 1718150400, 'moon_phase': 0.2, 'summary': 'Expect a day of partly cloudy with rain', 'temp': {'day': 15.29, 'min': 7.38, 'max': 16.28, 'night': 10.7, 'eve': 15.76, 'morn': 11.04}, 'feels_like': {'day': 14.47, 'night': 9.78, 'eve': 15.06, 'morn': 10.29}, 'pressure': 1022, 'humidity': 61, 'dew_point': 7.73, 'wind_speed': 6.3, 'wind_deg': 319, 'wind_gust': 6.56, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 55, 'pop': 0.45, 'rain': 0.25, 'uvi': 6.18}, {'dt': 1718280000, 'sunrise': 1718251393, 'sunset': 1718309357, 'moonrise': 1718276820, 'moonset': 1718237700, 'moon_phase': 0.23, 'summary': 'Expect a day of partly cloudy with rain', 'temp': {'day': 16.06, 'min': 7.33, 'max': 16.81, 'night': 11.23, 'eve': 12.3, 'morn': 9.43}, 'feels_like': {'day': 15.58, 'night': 10.84, 'eve': 11.81, 'morn': 7.57}, 'pressure': 1015, 'humidity': 71, 'dew_point': 10.55, 'wind_speed': 8.59, 'wind_deg': 195, 'wind_gust': 15.64, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'clouds': 100, 'pop': 1, 'rain': 2.75, 'uvi': 4.79}, {'dt': 1718366400, 'sunrise': 1718337786, 'sunset': 1718395788, 'moonrise': 1718367240, 'moonset': 1718324880, 'moon_phase': 0.25, 'summary': 'Expect a day of partly cloudy with rain', 'temp': {'day': 17.38, 'min': 11.89, 'max': 17.5, 'night': 12.25, 'eve': 15.84, 'morn': 12.8}, 'feels_like': {'day': 17.13, 'night': 11.8, 'eve': 15.39, 'morn': 12.59}, 'pressure': 1006, 'humidity': 75, 'dew_point': 12.74, 'wind_speed': 9.26, 'wind_deg': 225, 'wind_gust': 15.64, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 92, 'pop': 1, 'rain': 6.37, 'uvi': 6.68}, {'dt': 1718452800, 'sunrise': 1718424181, 'sunset': 1718482217, 'moonrise': 1718457660, 'moonset': 1718412060, 'moon_phase': 0.29, 'summary': 'Expect a day of partly cloudy with rain', 'temp': {'day': 16.66, 'min': 9.07, 'max': 17.25, 'night': 14.37, 'eve': 15.95, 'morn': 11.19}, 'feels_like': {'day': 16.16, 'night': 13.93, 'eve': 15.56, 'morn': 10.58}, 'pressure': 1008, 'humidity': 68, 'dew_point': 10.65, 'wind_speed': 9.58, 'wind_deg': 234, 'wind_gust': 13.49, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 43, 'pop': 1, 'rain': 2.34, 'uvi': 6.5}, {'dt': 1718539200, 'sunrise': 1718510580, 'sunset': 1718568642, 'moonrise': 1718548080, 'moonset': 1718499180, 'moon_phase': 0.32, 'summary': 'You can expect partly cloudy in the morning, with rain in the afternoon', 'temp': {'day': 18.16, 'min': 11.11, 'max': 19.81, 'night': 14.35, 'eve': 16.94, 'morn': 13.11}, 'feels_like': {'day': 17.78, 'night': 14.22, 'eve': 16.83, 'morn': 12.88}, 'pressure': 1010, 'humidity': 67, 'dew_point': 11.67, 'wind_speed': 6.7, 'wind_deg': 216, 'wind_gust': 11.27, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': 72, 'pop': 0.83, 'rain': 1.67, 'uvi': 5.78}, {'dt': 1718625600, 'sunrise': 1718596981, 'sunset': 1718655065, 'moonrise': 1718638680, 'moonset': 1718586420, 'moon_phase': 0.35, 'summary': 'Expect a day of partly cloudy with rain', 'temp': {'day': 19.99, 'min': 14.44, 'max': 20.52, 'night': 16.33, 'eve': 19.66, 'morn': 14.95}, 'feels_like': {'day': 20.13, 'night': 16.42, 'eve': 19.87, 'morn': 15.03}, 'pressure': 1013, 'humidity': 80, 'dew_point': 16.29, 'wind_speed': 4.6, 'wind_deg': 251, 'wind_gust': 6.54, 'weather': [{'id': 501, 'main' ...

# %%
# Fonction pour extraire les données de la colonne weather
def extract_combined_weather_features(row):
    try:
        # Tente de convertir la chaîne météo en JSON, sinon convertit en dictionnaire
        if isinstance(row['Weather'], str) and row['Weather'].strip().startswith('{'):
            try:
                weather_data = json.loads(row['Weather'])
            except json.JSONDecodeError:
                weather_data = ast.literal_eval(row['Weather'].replace("'", '"'))
        else:
            weather_data = ast.literal_eval(row['Weather'])
        
        daily_data = weather_data['daily'] # Accède aux données journalières
        
       # Calculs pour les  mesures météorologiques à extraire
        max_temp = max(day['temp']['max'] for day in daily_data)
        min_temp = min(day['temp']['min'] for day in daily_data)
        avg_temp = sum(day['temp']['day'] for day in daily_data) / len(daily_data)
        avg_humidity = sum(day['humidity'] for day in daily_data) / len(daily_data)
        weather_descriptions = ', '.join(set(day['weather'][0]['description'] for day in daily_data))
        avg_wind_speed = sum(day['wind_speed'] for day in daily_data) / len(daily_data)
        max_uv = max(day['uvi'] for day in daily_data)
        total_precip = sum(day.get('rain', 0) for day in daily_data)
        avg_pressure = sum(day['pressure'] for day in daily_data) / len(daily_data)
        
        # Retourne toutes les mesures calculées sous forme de série
        return pd.Series([max_temp, min_temp, avg_temp, avg_humidity, weather_descriptions, avg_wind_speed, max_uv, total_precip, avg_pressure])
    except Exception as e:
        print(f"Error processing row: {e}")
        return pd.Series([None] * 9) # Retourne None pour chaque attribut en cas d'erreur

# Application de la fonction sur df_s3 pour enrichir les données
df_s3[['MaxTemp', 'MinTemp', 'AvgTemp', 'AvgHumidity', 'WeatherDesc', 'AvgWindSpeed', 'MaxUV', 'TotalPrecip', 'AvgPressure']] = df_s3.apply(extract_combined_weather_features, axis=1)

# %%
# Affiche les premières lignes pour vérifier les nouvelles données
df_s3.head()
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#     Latitude  Longitude                                            Weather  \
# 0  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 2  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 3  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 4  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
#
#    ...  TotalPrecipitation  MaxTemp  MinTemp   AvgTemp  AvgHumidity  \
# 0  ...               23.87    21.93     7.33  18.28375       69.375
# 1  ...               23.87    21.93     7.33  18.28375       69.375
# 2  ...               23.87    21.93     7.33  18.28375       69.375
# 3  ...               23.87    21.93     7.33  18.28375       69.375
# 4  ...               23.87    21.93     7.33  18.28375       69.375
#
#                                          WeatherDesc AvgWindSpeed  MaxUV  \
# 0  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 1  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 2  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 3  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 4  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
#
#    TotalPrecip  AvgPressure
# 0        23.87     1014.125
# 1        23.87     1014.125
# 2        23.87     1014.125
# 3        23.87     1014.125
# 4        23.87     1014.125
#
# [5 rows x 21 columns]

# %% [markdown]
# Ces mesures météorologiques sont utiles pour optimiser les recommandations de destinations de voyage sur Kayak. Elles permettent d'évaluer le confort climatique (températures extrêmes et moyennes), le ressenti (humidité, pression), et les conditions météo potentielles (précipitations, vitesse du vent, UV), fournissant ainsi une base solide pour des suggestions personnalisées et pertinentes aux utilisateurs planifiant leurs voyages.

# %%
# Qualification en df_final_s3
df_final_s3= df_s3

# %% [markdown]
# ## Stocker les données transformées dans une base de données RDS

# %% [markdown]
# Nous établissons une connexion à une base de données PostgreSQL et y insérons df_final_s3 dans une table portant le même nom.
#
# Ensuite, nous exécutons une requête SQL pour récupérer et afficher les cinq premières lignes de la table afin de vérifier que les données ont été correctement transférées pour des analyses ultérieures.

# %%
# Connexion à la base de données PostgreSQL et insertion du DataFrame 'df_final_s3' dans la table 'df_final_s3'.
username = 'postgres'
password = 'omaromar'
host = 'kayak-project-db.c34qui6ye7rw.eu-north-1.rds.amazonaws.com'
port = '5432'
database = 'postgres'

# Création de l'engine de la database
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

# Transpose les DataFrames dans la database
table_name = 'df_final_s3'
df_final_s3.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 876

# %%
# Test des datas avec une requête
query = text("SELECT * FROM df_final_s3 LIMIT 5")
pd.read_sql(query, engine)
# Out:
#                 City                 Hotel Name  \
# 0  Mont Saint Michel                 Hôtel Vert
# 1  Mont Saint Michel      Les Terrasses Poulard
# 2  Mont Saint Michel  Mercure Mont Saint Michel
# 3  Mont Saint Michel           Le Relais Du Roy
# 4  Mont Saint Michel     Le Relais Saint Michel
#
#                                            Hotel URL  Score  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...    8.0
# 1  https://www.booking.com/hotel/fr/les-terrasses...    7.4
# 2  https://www.booking.com/hotel/fr/mont-saint-mi...    8.2
# 3  https://www.booking.com/hotel/fr/le-relais-du-...    8.1
# 4  https://www.booking.com/hotel/fr/le-relais-sai...    8.0
#
#                                          Description  lat_hotels  lon_hotels  \
# 0  Hotel Vert offers pastel-coloured rooms with a...   48.614700   -1.509617
# 1  Composed of 2 different buildings, Les Terrass...   48.635349   -1.510379
# 2  This Mercure is situated in parkland just 2 km...   48.614247   -1.510545
# 3  Le Relais Du Roy is a 3-star hotel situated ne...   48.616263   -1.510906
# 4  Le Relais Saint Michel is an hotel facing the ...   48.617587   -1.510396
#
#     Latitude  Longitude                                            Weather  \
# 0  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 1  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 2  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 3  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
# 4  48.635954   -1.51146  {'lat': 48.636, 'lon': -1.5115, 'timezone': 'E...
#
#    ...  TotalPrecipitation  MaxTemp  MinTemp   AvgTemp  AvgHumidity  \
# 0  ...               23.87    21.93     7.33  18.28375       69.375
# 1  ...               23.87    21.93     7.33  18.28375       69.375
# 2  ...               23.87    21.93     7.33  18.28375       69.375
# 3  ...               23.87    21.93     7.33  18.28375       69.375
# 4  ...               23.87    21.93     7.33  18.28375       69.375
#
#                                          WeatherDesc AvgWindSpeed  MaxUV  \
# 0  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 1  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 2  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 3  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
# 4  moderate rain, overcast clouds, light rain, sc...         7.02   6.68
#
#    TotalPrecip  AvgPressure
# 0        23.87     1014.125
# 1        23.87     1014.125
# 2        23.87     1014.125
# 3        23.87     1014.125
# 4        23.87     1014.125
#
# [5 rows x 21 columns]
